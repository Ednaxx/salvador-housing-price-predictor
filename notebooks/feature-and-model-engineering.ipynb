# %% [markdown]
# # Feature Engineering and Model selection

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/housing_data.csv", index_col="id")

# Missing neighborhood set to NaN
df.neighborhood = df.neighborhood.apply(lambda x: np.nan if x == "BA" else x)

# Drop null prices and areas over 2000m^2
df = df[~(df.prices.isna())]
df = df[~(df.areas > 2000)]

# %% [markdown]
# ### Our data

# %%
df.head()
# Out:
#             areas  bedrooms  bathrooms  parkingSpots    prices       type  \
# id
# 2669329904  324.0       5.0        3.0           4.0  340000.0      house
# 2667338201   51.0       2.0        1.5           1.0  295000.0        NaN
# 2643720430   94.0       3.0        4.0           2.0  629000.0  apartment
# 2681509397   66.0       2.0        2.0           2.0  460000.0  apartment
# 2671493238   82.0       3.0        3.0           2.0  649990.0  apartment
#
#              neighborhood
# id
# 2669329904       Sao Tome
# 2667338201   Santa Teresa
# 2643720430  Cidade Jardim
# 2681509397          Imbuí
# 2671493238          Piatã

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1093 entries, 2669329904 to 2682107804
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   areas         1093 non-null   float64
#  1   bedrooms      1092 non-null   float64
#  2   bathrooms     1092 non-null   float64
#  3   parkingSpots  913 non-null    float64
#  4   prices        1093 non-null   float64
#  5   type          1088 non-null   object
#  6   neighborhood  1069 non-null   object
# dtypes: float64(5), object(2)
# memory usage: 68.3+ KB

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Neighborhood Price/Area

# %% [markdown]
# Since this relationship behaves differently for apartments/houses. We'll have different values for each.

# %%
neighborhood_house_price_sum =  df[df.type == "house"].groupby("neighborhood").prices.sum()
neighborhood_house_area_sum =  df[df.type == "house"].groupby("neighborhood").areas.sum()

neighborhood_apartment_price_sum =  df[df.type == "apartment"].groupby("neighborhood").prices.sum()
neighborhood_apartment_area_sum =  df[df.type == "apartment"].groupby("neighborhood").areas.sum()

neighborhood_house_area_price = neighborhood_house_price_sum / neighborhood_house_area_sum
neighborhood_apartment_area_price = neighborhood_apartment_price_sum / neighborhood_apartment_area_sum


neighborhoods_area_price = pd.DataFrame({
    "neighborhood_apartment_area_price": neighborhood_apartment_area_price,
    "neighborhood_house_area_price": neighborhood_house_area_price
    })

# %%
def set_neighborhood_area_price(x):
    if x.type == "house" and x.neighborhood in neighborhood_house_area_price:
        return neighborhoods_area_price.loc[x.neighborhood]["neighborhood_house_area_price"]
    elif x.type == "apartment" and x.neighborhood in neighborhood_apartment_area_price:
        return neighborhoods_area_price.loc[x.neighborhood]["neighborhood_apartment_area_price"]
    else: return np.nan

df["neighborhood_area_price"] = df.apply(set_neighborhood_area_price, axis=1)
df.head()
# Out:
#             areas  bedrooms  bathrooms  parkingSpots    prices       type  \
# id
# 2669329904  324.0       5.0        3.0           4.0  340000.0      house
# 2667338201   51.0       2.0        1.5           1.0  295000.0        NaN
# 2643720430   94.0       3.0        4.0           2.0  629000.0  apartment
# 2681509397   66.0       2.0        2.0           2.0  460000.0  apartment
# 2671493238   82.0       3.0        3.0           2.0  649990.0  apartment
#
#              neighborhood  neighborhood_area_price
# id
# 2669329904       Sao Tome               791.738382
# 2667338201   Santa Teresa                      NaN
# 2643720430  Cidade Jardim              6811.209440
# 2681509397          Imbuí              6091.301222
# 2671493238          Piatã              6921.176471

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Prepare training data

# %%
df.type = df.type.replace({"house": 0, "apartment": 1})

X = df.drop("prices", axis=1)
y = df.prices

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Set Pipeline function

# %%
def create_pipeline(model, training_data):
    numerical_cols = training_data.select_dtypes(include='number').columns
    categorical_cols = training_data.select_dtypes(include='object').columns

    # Preprocessing for numerical data
    numerical_transformer = SimpleImputer(strategy='median')

    # Preprocessing for categorical data
    categorical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder(handle_unknown='ignore'))
    ])

    #Bundling
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numerical_transformer, numerical_cols),
            ('cat', categorical_transformer, categorical_cols)
        ])

    return Pipeline(steps=[('preprocessor', preprocessor), ('model', model)])

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

pipe = create_pipeline(RandomForestRegressor(random_state=1, n_jobs=6), X)

# %% [markdown]
# #### Grid Search

# %%
params = {
    "model__n_estimators" : [100, 250, 300, 500],
    'model__bootstrap': [True, False],
    "model__max_depth" : [2, 5, 10, None]
}

cv = GridSearchCV(pipe, params, cv=5, scoring=["r2", "neg_mean_absolute_error"], refit="r2", verbose=2)

# %%
cv.fit(X, y)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=250; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=250; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=250; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=250; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=250; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=300; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=300; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=300; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=300; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=300; total time=   0.4s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=500; total time=   0.6s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=500; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=500; total time=   0.6s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=500; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=2, model__n_estimators=500; total time=   0.6s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=250; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=250; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=250; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=250; total time=   0.4s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=250; total time=   0.4s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=300; total time=   0.4s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=300; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=300; total time=   0.4s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=300; total time=   0.4s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=300; total time=   0.4s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=500; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=500; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=500; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=500; total time=   0.6s
# [CV] END model__bootstrap=True, model__max_depth=5, model__n_estimators=500; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=250; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=250; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=250; total time=   0.6s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=250; total time=   0.5s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=250; total time=   0.6s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=500; total time=   1.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=500; total time=   1.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=500; total time=   1.3s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=500; total time=   1.2s
# [CV] END model__bootstrap=True, model__max_depth=10, model__n_estimators=500; total time=   1.1s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=100; total time=   0.4s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=100; total time=   0.4s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=250; total time=   0.9s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=250; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=250; total time=   0.9s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=250; total time=   0.9s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=250; total time=   0.8s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=300; total time=   1.0s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=300; total time=   1.1s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=300; total time=   1.0s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=300; total time=   1.2s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=300; total time=   1.1s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=500; total time=   1.8s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=500; total time=   1.9s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=500; total time=   1.8s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=500; total time=   1.8s
# [CV] END model__bootstrap=True, model__max_depth=None, model__n_estimators=500; total time=   1.8s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=100; total time=   0.0s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=100; total time=   0.0s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=100; total time=   0.0s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=100; total time=   0.0s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=250; total time=   0.2s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=250; total time=   0.2s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=250; total time=   0.2s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=250; total time=   0.2s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=250; total time=   0.1s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=300; total time=   0.2s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=300; total time=   0.2s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=300; total time=   0.2s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=300; total time=   0.2s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=300; total time=   0.2s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=500; total time=   0.4s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=500; total time=   0.4s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=500; total time=   0.4s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=500; total time=   0.4s
# [CV] END model__bootstrap=False, model__max_depth=2, model__n_estimators=500; total time=   0.4s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=100; total time=   0.1s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=250; total time=   0.3s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=250; total time=   0.3s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=250; total time=   0.2s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=250; total time=   0.3s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=250; total time=   0.2s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=300; total time=   0.3s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=300; total time=   0.3s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=300; total time=   0.3s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=300; total time=   0.3s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=300; total time=   0.3s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=500; total time=   0.5s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=500; total time=   0.5s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=500; total time=   0.6s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=500; total time=   0.6s
# [CV] END model__bootstrap=False, model__max_depth=5, model__n_estimators=500; total time=   0.6s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=100; total time=   0.2s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=100; total time=   0.3s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=250; total time=   0.7s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=250; total time=   0.6s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=250; total time=   0.5s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=250; total time=   0.5s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=250; total time=   0.5s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=300; total time=   0.6s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=300; total time=   0.7s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=300; total time=   0.6s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=500; total time=   1.2s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=500; total time=   1.4s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=500; total time=   1.1s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=500; total time=   1.1s
# [CV] END model__bootstrap=False, model__max_depth=10, model__n_estimators=500; total time=   1.0s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=100; total time=   0.4s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=100; total time=   0.4s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=100; total time=   0.4s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=100; total time=   0.5s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=100; total time=   0.5s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=250; total time=   1.1s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=250; total time=   1.2s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=250; total time=   1.3s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=250; total time=   1.2s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=250; total time=   1.2s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=300; total time=   1.6s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=300; total time=   1.5s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=300; total time=   1.5s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=300; total time=   1.3s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=300; total time=   1.3s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=500; total time=   2.4s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=500; total time=   2.3s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=500; total time=   2.2s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=500; total time=   2.1s
# [CV] END model__bootstrap=False, model__max_depth=None, model__n_estimators=500; total time=   2.3s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(strategy='median'),
#                                                                          Index(['areas', 'bedrooms', 'bathrooms', 'parkingSpots', 'type',
#        'neighborhood_area_price'],
#       dtype='object')),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          Index(['neighborhood'], dtype='object'))])),
#                                        ('model',
#                                         RandomForestRegressor(n_jobs=6,
#                                                               random_state=1))]),
#              param_grid={'model__bootstrap': [True, False],
#                          'model__max_depth': [2, 5, 10, None],
#                          'model__n_estimators': [100, 250, 300, 500]},
#              refit='r2', scoring=['r2', 'neg_mean_absolute_error'], verbose=2)

# %%
random_forest_results = pd.DataFrame(cv.cv_results_)
random_forest_results[["mean_fit_time", "mean_score_time", "param_model__bootstrap", "param_model__n_estimators", "param_model__max_depth",
          "mean_test_r2", "rank_test_r2", "mean_test_neg_mean_absolute_error", "std_test_neg_mean_absolute_error"]].sort_values("rank_test_r2").head()
# Out:
#     mean_fit_time  mean_score_time param_model__bootstrap  \
# 12       0.413670         0.030209                   True
# 14       1.131139         0.057286                   True
# 13       0.912024         0.051540                   True
# 15       1.833111         0.083958                   True
# 10       0.725104         0.056530                   True
#
#    param_model__n_estimators param_model__max_depth  mean_test_r2  \
# 12                       100                   None      0.847245
# 14                       300                   None      0.846965
# 13                       250                   None      0.846522
# 15                       500                   None      0.844567
# 10                       300                     10      0.843565
#
#     rank_test_r2  mean_test_neg_mean_absolute_error  \
# 12             1                      -41570.670935
# 14             2                      -41782.795390
# 13             3                      -41794.885865
# 15             4                      -41901.289611
# 10             5                      -41665.203435
#
#     std_test_neg_mean_absolute_error
# 12                       6111.525103
# 14                       6353.022848
# 13                       6402.512134
# 15                       6333.126408
# 10                       6308.913996

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBRegressor

pipe = create_pipeline(XGBRegressor(random_state=1, n_jobs=6), X)

# %% [markdown]
# #### GridSearchCV

# %%
params = {
    "model__n_estimators" : [200, 300, 500],
    'model__learning_rate': [0.01, 0.05, 0.1],
    "model__max_depth" : [2, 5, 10, None]
}

cv = GridSearchCV(pipe, params, cv=5, scoring=["r2", "neg_mean_absolute_error"], refit="r2", verbose=2)

# %%
cv.fit(X, y)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=500; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=500; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=500; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=500; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=2, model__n_estimators=500; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=5, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=10, model__n_estimators=200; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=10, model__n_estimators=200; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=10, model__n_estimators=200; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=10, model__n_estimators=200; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=10, model__n_estimators=200; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=10, model__n_estimators=300; total time=   0.5s
# [CV] END model__learning_rate=0.01, model__max_depth=10, model__n_estimators=300; total time=   0.3s
# [CV] END model__learning_rate=0.01, model__max_depth=10, model__n_estimators=300; total time=   0.3s
# [CV] END model__learning_rate=0.01, model__max_depth=10, model__n_estimators=300; total time=   0.2s
# [CV] END model__learning_rate=0.01, model__max_depth=10, model__n_estimators=300; total time=   0.3s
# [CV] END model__learning_rate=0.01, model__max_depth=10, model__n_estimators=500; total time=   0.5s
# [CV] END model__learning_rate=0.01, model__max_depth=10, model__n_estimators=500; total time=   0.6s
# [CV] END model__learning_rate=0.01, model__max_depth=10, model__n_estimators=500; total time=   0.5s
# [CV] END model__learning_rate=0.01, model__max_depth=10, model__n_estimators=500; total time=   0.4s
# [CV] END model__learning_rate=0.01, model__max_depth=10, model__n_estimators=500; total time=   0.5s
# [CV] END model__learning_rate=0.01, model__max_depth=None, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=None, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=None, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=None, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=None, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.01, model__max_depth=None, model__n_estimators=300; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=None, model__n_estimators=300; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=None, model__n_estimators=300; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=None, model__n_estimators=300; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=None, model__n_estimators=300; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=None, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=None, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=None, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=None, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.01, model__max_depth=None, model__n_estimators=500; total time=   0.2s
# [CV] END model__learning_rate=0.05, model__max_depth=2, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=2, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=2, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=2, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=2, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=2, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=2, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=2, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=2, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=2, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=2, model__n_estimators=500; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=2, model__n_estimators=500; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=2, model__n_estimators=500; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=2, model__n_estimators=500; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=2, model__n_estimators=500; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=5, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=200; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=200; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=200; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=200; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=200; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=300; total time=   0.2s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=300; total time=   0.2s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=300; total time=   0.3s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=300; total time=   0.2s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=300; total time=   0.2s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=500; total time=   0.3s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=500; total time=   0.3s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=500; total time=   0.3s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=500; total time=   0.3s
# [CV] END model__learning_rate=0.05, model__max_depth=10, model__n_estimators=500; total time=   0.3s
# [CV] END model__learning_rate=0.05, model__max_depth=None, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=None, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=None, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=None, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=None, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=None, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=None, model__n_estimators=300; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=None, model__n_estimators=300; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=None, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=None, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.05, model__max_depth=None, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=None, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=None, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=None, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.05, model__max_depth=None, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=2, model__n_estimators=500; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=5, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=200; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=200; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=200; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=200; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=200; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=300; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=300; total time=   0.2s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=300; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=300; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=300; total time=   0.2s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=500; total time=   0.3s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=500; total time=   0.3s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=500; total time=   0.3s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=500; total time=   0.3s
# [CV] END model__learning_rate=0.1, model__max_depth=10, model__n_estimators=500; total time=   0.3s
# [CV] END model__learning_rate=0.1, model__max_depth=None, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=None, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=None, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=None, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=None, model__n_estimators=200; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=None, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=None, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=None, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=None, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=None, model__n_estimators=300; total time=   0.0s
# [CV] END model__learning_rate=0.1, model__max_depth=None, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=None, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=None, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=None, model__n_estimators=500; total time=   0.1s
# [CV] END model__learning_rate=0.1, model__max_depth=None, model__n_estimators=500; total time=   0.1s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(strategy='median'),
#                                                                          Index(['areas', 'bedrooms', 'bathrooms', 'parkingSpots', 'type',
#        'neighborhood_area_price'],
#       dtype='object')),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder(handle_unknown=...
#                                                      max_leaves=None,
#                                                      min_child_weight=None,
#                                                      missing=nan,
#                                                      monotone_constraints=None,
#                                                      multi_strategy=None,
#                                                      n_estimators=None,
#                                                      n_jobs=6,
#                                                      num_parallel_tree=None,
#                                                      random_state=1, ...))]),
#              param_grid={'model__learning_rate': [0.01, 0.05, 0.1],
#                          'model__max_depth': [2, 5, 10, None],
#                          'model__n_estimators': [200, 300, 500]},
#              refit='r2', scoring=['r2', 'neg_mean_absolute_error'], verbose=2)

# %%
xgboost_results = pd.DataFrame(cv.cv_results_)
xgboost_results[["mean_fit_time", "mean_score_time", "param_model__n_estimators", "param_model__learning_rate", "param_model__max_depth",
          "mean_test_r2", "rank_test_r2","mean_test_neg_mean_absolute_error", "std_test_neg_mean_absolute_error"]].sort_values("rank_test_r2").head()
# Out:
#     mean_fit_time  mean_score_time param_model__n_estimators  \
# 26       0.088754         0.005810                       500
# 25       0.057380         0.006207                       300
# 14       0.098352         0.006009                       500
# 12       0.042657         0.005914                       200
# 13       0.058174         0.005307                       300
#
#    param_model__learning_rate param_model__max_depth  mean_test_r2  \
# 26                        0.1                      2      0.831745
# 25                        0.1                      2      0.828644
# 14                       0.05                      2      0.826579
# 12                       0.05                      2      0.825768
# 13                       0.05                      2      0.825052
#
#     rank_test_r2  mean_test_neg_mean_absolute_error  \
# 26             1                      -45289.274162
# 25             2                      -45545.068180
# 14             3                      -45998.690357
# 12             4                      -45898.799486
# 13             5                      -45917.507206
#
#     std_test_neg_mean_absolute_error
# 26                       4080.812463
# 25                       3821.981125
# 14                       4246.079137
# 12                       4490.330377
# 13                       4377.245132
