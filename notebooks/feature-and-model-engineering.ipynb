# %% [markdown]
# # Feature Engineering and Model selection

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/housing_data.csv", index_col="id")

# Missing neighborhood set to NaN
df.neighborhood = df.neighborhood.apply(lambda x: np.nan if x == "BA" else x)

# Drop null prices and outliers
df = df[~(df.prices.isna())]
df = df[~(df.areas > 200)]
df = df[~(df.bedrooms > 5)]
df = df[~(df.bathrooms > 5)]
df = df[~(df.parkingSpots > 5)]
df = df[~(df.prices > 1700000)]

# %% [markdown]
# ### Our data

# %%
df.head()
# Out:
#             areas  bedrooms  bathrooms  parkingSpots    prices       type  \
# id
# 2667338201   51.0       2.0        1.5           1.0  295000.0        NaN
# 2643720430   94.0       3.0        4.0           2.0  629000.0  apartment
# 2681509397   66.0       2.0        2.0           2.0  460000.0  apartment
# 2671493238   82.0       3.0        3.0           2.0  649990.0  apartment
# 2592933397   50.0       2.0        1.0           1.0  184900.0  apartment
#
#              neighborhood
# id
# 2667338201   Santa Teresa
# 2643720430  Cidade Jardim
# 2681509397          Imbuí
# 2671493238          Piatã
# 2592933397   Luís Anselmo

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1935 entries, 2667338201 to 2639465330
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   areas         1935 non-null   float64
#  1   bedrooms      1931 non-null   float64
#  2   bathrooms     1933 non-null   float64
#  3   parkingSpots  1627 non-null   float64
#  4   prices        1935 non-null   float64
#  5   type          1925 non-null   object
#  6   neighborhood  1906 non-null   object
# dtypes: float64(5), object(2)
# memory usage: 120.9+ KB

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Neighborhood Price/Area

# %% [markdown]
# Since this relationship behaves differently for apartments/houses. We'll have different values for each.

# %%
neighborhood_house_price_sum =  df[df.type == "house"].groupby("neighborhood").prices.sum()
neighborhood_house_area_sum =  df[df.type == "house"].groupby("neighborhood").areas.sum()

neighborhood_apartment_price_sum =  df[df.type == "apartment"].groupby("neighborhood").prices.sum()
neighborhood_apartment_area_sum =  df[df.type == "apartment"].groupby("neighborhood").areas.sum()


neighborhoods_area_price = pd.DataFrame({
    "neighborhood_apartment_area_price": neighborhood_apartment_price_sum / neighborhood_apartment_area_sum,
    "neighborhood_house_area_price": neighborhood_house_price_sum / neighborhood_house_area_sum
    })

# %%
def set_neighborhood_area_price(x):
    if x.type == "house" and x.neighborhood in neighborhoods_area_price.index:
        return neighborhoods_area_price.loc[x.neighborhood]["neighborhood_house_area_price"]
    elif x.type == "apartment" and x.neighborhood in neighborhoods_area_price.index:
        return neighborhoods_area_price.loc[x.neighborhood]["neighborhood_apartment_area_price"]
    else: return np.nan

df["neighborhood_area_price"] = df.apply(set_neighborhood_area_price, axis=1)
df.head()
# Out:
#             areas  bedrooms  bathrooms  parkingSpots    prices       type  \
# id
# 2667338201   51.0       2.0        1.5           1.0  295000.0        NaN
# 2643720430   94.0       3.0        4.0           2.0  629000.0  apartment
# 2681509397   66.0       2.0        2.0           2.0  460000.0  apartment
# 2671493238   82.0       3.0        3.0           2.0  649990.0  apartment
# 2592933397   50.0       2.0        1.0           1.0  184900.0  apartment
#
#              neighborhood  neighborhood_area_price
# id
# 2667338201   Santa Teresa                      NaN
# 2643720430  Cidade Jardim              6641.723356
# 2681509397          Imbuí              6118.134938
# 2671493238          Piatã              6270.982143
# 2592933397   Luís Anselmo              3789.516129

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Prepare training data

# %%
df.type = df.type.replace({"house": 0, "apartment": 1})

X = df.drop("prices", axis=1)
y = df.prices

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Set Pipeline function

# %%
def create_pipeline(model, training_data):
    numerical_cols = training_data.select_dtypes(include='number').columns
    categorical_cols = training_data.select_dtypes(include='object').columns

    # Preprocessing for numerical data
    numerical_transformer = SimpleImputer(strategy='median')

    # Preprocessing for categorical data
    categorical_transformer = Pipeline(steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('onehot', OneHotEncoder(handle_unknown='ignore'))
    ])

    #Bundling
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numerical_transformer, numerical_cols),
            ('cat', categorical_transformer, categorical_cols)
        ])

    return Pipeline(steps=[('preprocessor', preprocessor), ('model', model)])

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

pipe = create_pipeline(RandomForestRegressor(random_state=1, n_jobs=6), X)

# %% [markdown]
# #### Grid Search

# %%
params = {
    "model__n_estimators" : [100, 250, 300, 500],
    'model__bootstrap': [True, False],
    "model__max_depth" : [2, 5, 10, None]
}

cv = GridSearchCV(pipe, params, cv=5, scoring=["r2", "neg_mean_absolute_error"], refit="r2", verbose=2)

# %%
# cv.fit(X, y)

# %%
# random_forest_results = pd.DataFrame(cv.cv_results_)
# random_forest_results[["mean_fit_time", "mean_score_time", "param_model__bootstrap", "param_model__n_estimators", "param_model__max_depth",
#           "mean_test_r2", "rank_test_r2", "mean_test_neg_mean_absolute_error", "std_test_neg_mean_absolute_error"]].sort_values("rank_test_r2").head()

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBRegressor

pipe = create_pipeline(XGBRegressor(random_state=1, n_jobs=6), X)

# %% [markdown]
# #### GridSearchCV

# %%
params = {
    "model__n_estimators" : [200, 300, 500],
    'model__learning_rate': [0.05],
    "model__max_depth" : [2],
    'model__min_child_weight':[10,12],
    "model__gamma": [2,4,6]
}

cv = GridSearchCV(pipe, params, cv=5, scoring=["r2", "neg_mean_absolute_error"], refit="r2", verbose=2)

# %%
cv.fit(X, y)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=200; total time=   0.1s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=300; total time=   0.1s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=2, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=4, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=7, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=9, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=10, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=200; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=300; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=500; total time=   0.0s
# [CV] END model__gamma=6, model__learning_rate=0.05, model__max_depth=2, model__min_child_weight=12, model__n_estimators=500; total time=   0.0s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          SimpleImputer(strategy='median'),
#                                                                          Index(['areas', 'bedrooms', 'bathrooms', 'parkingSpots', 'type',
#        'neighborhood_area_price'],
#       dtype='object')),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder(handle_unknown=...
#                                                      missing=nan,
#                                                      monotone_constraints=None,
#                                                      multi_strategy=None,
#                                                      n_estimators=None,
#                                                      n_jobs=6,
#                                                      num_parallel_tree=None,
#                                                      random_state=1, ...))]),
#              param_grid={'model__gamma': [2, 4, 6],
#                          'model__learning_rate': [0.05],
#                          'model__max_depth': [2],
#                          'model__min_child_weight': [7, 9, 10, 12],
#                          'model__n_estimators': [200, 300, 500]},
#              refit='r2', scoring=['r2', 'neg_mean_absolute_error'], verbose=2)

# %%
xgboost_results = pd.DataFrame(cv.cv_results_)
xgboost_results.sort_values("rank_test_r2").head(10)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 35       0.091711      0.001470         0.006400        0.000490
# 23       0.092855      0.001518         0.006400        0.000490
# 11       0.102348      0.017956         0.006401        0.001021
# 31       0.061009      0.001676         0.006001        0.000002
# 7        0.061907      0.001319         0.006102        0.000203
# 19       0.061307      0.001629         0.005600        0.000490
# 4        0.063344      0.002042         0.006201        0.000401
# 28       0.061109      0.000372         0.005902        0.000196
# 16       0.060408      0.001797         0.006400        0.000491
# 22       0.063608      0.003119         0.005800        0.000400
#
#    param_model__gamma param_model__learning_rate param_model__max_depth  \
# 35                  6                       0.05                      2
# 23                  4                       0.05                      2
# 11                  2                       0.05                      2
# 31                  6                       0.05                      2
# 7                   2                       0.05                      2
# 19                  4                       0.05                      2
# 4                   2                       0.05                      2
# 28                  6                       0.05                      2
# 16                  4                       0.05                      2
# 22                  4                       0.05                      2
#
#    param_model__min_child_weight param_model__n_estimators  \
# 35                            12                       500
# 23                            12                       500
# 11                            12                       500
# 31                            10                       300
# 7                             10                       300
# 19                            10                       300
# 4                              9                       300
# 28                             9                       300
# 16                             9                       300
# 22                            12                       300
#
#                                                params  ...  std_test_r2  \
# 35  {'model__gamma': 6, 'model__learning_rate': 0....  ...     0.045804
# 23  {'model__gamma': 4, 'model__learning_rate': 0....  ...     0.045804
# 11  {'model__gamma': 2, 'model__learning_rate': 0....  ...     0.045804
# 31  {'model__gamma': 6, 'model__learning_rate': 0....  ...     0.049065
# 7   {'model__gamma': 2, 'model__learning_rate': 0....  ...     0.049065
# 19  {'model__gamma': 4, 'model__learning_rate': 0....  ...     0.049065
# 4   {'model__gamma': 2, 'model__learning_rate': 0....  ...     0.048855
# 28  {'model__gamma': 6, 'model__learning_rate': 0....  ...     0.048855
# 16  {'model__gamma': 4, 'model__learning_rate': 0....  ...     0.048855
# 22  {'model__gamma': 4, 'model__learning_rate': 0....  ...     0.047569
#
#     rank_test_r2  split0_test_neg_mean_absolute_error  \
# 35             1                        -38744.835342
# 23             1                        -38744.835342
# 11             1                        -38744.835342
# 31             4                        -38602.062702
# 7              4                        -38602.062702
# 19             4                        -38602.062702
# 4              7                        -38588.979459
# 28             7                        -38588.979459
# 16             7                        -38588.979459
# 22            10                        -38696.871205
#
#     split1_test_neg_mean_absolute_error  split2_test_neg_mean_absolute_error  \
# 35                        -40348.192860                        -35620.056217
# 23                        -40348.192860                        -35620.056217
# 11                        -40348.192860                        -35620.056217
# 31                        -40166.078680                        -35695.152404
# 7                         -40166.078680                        -35695.152404
# 19                        -40166.078680                        -35695.152404
# 4                         -40747.788916                        -35728.791379
# 28                        -40747.788916                        -35728.791379
# 16                        -40747.788916                        -35728.791379
# 22                        -40163.475048                        -36050.304889
#
#     split3_test_neg_mean_absolute_error  split4_test_neg_mean_absolute_error  \
# 35                        -39515.037008                        -46937.841812
# 23                        -39515.037008                        -46937.841812
# 11                        -39515.037008                        -46937.841812
# 31                        -40595.971203                        -47352.917323
# 7                         -40595.971203                        -47352.917323
# 19                        -40595.971203                        -47352.917323
# 4                         -40511.661489                        -47374.185007
# 28                        -40511.661489                        -47374.185007
# 16                        -40511.661489                        -47374.185007
# 22                        -40539.067199                        -47244.276748
#
#     mean_test_neg_mean_absolute_error  std_test_neg_mean_absolute_error  \
# 35                      -40233.192648                       3714.230154
# 23                      -40233.192648                       3714.230154
# 11                      -40233.192648                       3714.230154
# 31                      -40482.436462                       3841.103325
# 7                       -40482.436462                       3841.103325
# 19                      -40482.436462                       3841.103325
# 4                       -40590.281250                       3839.052814
# 28                      -40590.281250                       3839.052814
# 16                      -40590.281250                       3839.052814
# 22                      -40538.799018                       3705.228127
#
#     rank_test_neg_mean_absolute_error
# 35                                  1
# 23                                  1
# 11                                  1
# 31                                 10
# 7                                  10
# 19                                 10
# 4                                  16
# 28                                 16
# 16                                 16
# 22                                 13
#
# [10 rows x 26 columns]
